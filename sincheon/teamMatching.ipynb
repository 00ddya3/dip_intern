# %%
import pandas as pd
import numpy as np
import re
import ipykernel

df1 = pd.read_csv('./rawdata/sincheon_minwon.csv')
df1.drop(columns=['Unnamed: 0'], inplace=True)
df1.head()
# Out:
#         부서                                      사업명  \
# 0    자연재난과                     무더운 대구의 여름을 위한 물놀이사업
# 1    공원녹지과                 신천동로 중앙분리대 교각 주변 녹지공간 조성
# 2   도시디자인과                  참 좋은 일자리가 만들어가는 학교 가는 길
# 3      NaN        침산교-금호대교 사이 오수배출시설 개선 및 보행자 교각 설치
# 4  여성가족정책관  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!”
#
#                                                 제안취지  \
# 0  대프리카라고 불리는 대구시에 물놀이장을 각 구마다 설치하여 주민들의 편의를 도모하는...
# 1  ○ 신천동로에 있는 신성교, 신천철도교, 신천교, 동신교 중앙분리대 교각 주변 나대...
# 2  효신초등학교 등굣길에 위치한 구 동부정류장 담벼락 보기 흉한 상태로 방치되어<br>...
# 3  침산교 – 금호대교 사이 오수 배출시설에 대한 환경 개선 및 보행자 통행을 위한 교...
# 4  일본군‘위안부’문제를 올바르게 해결하고 전쟁 없는 평화로운 미래와 여성인권<br>이...
#
#                                                 사업내용
# 0  현재 수도권지역이나 다른 광역시에서는 여름이 되면 각 구마다  물놀이를 할 수 있는...
# 1  ○ 신천동로 신성교, 신천철도교, 신천교, 동신교 교각 주변 녹지<br>  공간 조...
# 2  󰋻구 동부정류장 담장 도색 <br>󰋻보호 팬스 설치 후 장미넝쿨 식재<br>󰋻도색,...
# 3  ○ 신천과 금호강변은 많은 대구시민이 산책(걷기, 마라톤, 자전거 등)을 즐기는 곳...
# 4  § 사 업 명: 제8회평화와인권을위한대구시민걷기대회<br>“양성평등한 세상 함께 만...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   부서      431 non-null    object
#  1   사업명     500 non-null    object
#  2   제안취지    500 non-null    object
#  3   사업내용    500 non-null    object
# dtypes: object(4)
# memory usage: 15.8+ KB

# %%
#중복행 제거
df1 = df1.drop_duplicates(subset=['사업명'] ,keep='first')   # 사업명을 기준으로 중복 데이터 18개 삭제

#텍스트 정제
df1['제안취지'] = df1['제안취지'].str.replace(pat=r'[^\w]', repl=r'', regex=True)    # 특수문자 제거
df1['사업내용'] = df1['사업내용'].str.replace(pat=r'[^\w]', repl=r'', regex=True)    # 특수문자 제거
df1['제안취지'] = df1['제안취지'].str.replace('br', '')   # html 줄내림 표시 제거
df1['사업내용'] = df1['사업내용'].str.replace('br', '')   # html 줄내림 표시 제거
df1['사업내용'] = df1['사업내용'].str.replace('ㅁ', '')   # ㅁ 제거

df1.head()
# Out:
#         부서                                      사업명  \
# 0    자연재난과                     무더운 대구의 여름을 위한 물놀이사업
# 1    공원녹지과                 신천동로 중앙분리대 교각 주변 녹지공간 조성
# 2   도시디자인과                  참 좋은 일자리가 만들어가는 학교 가는 길
# 3      NaN        침산교-금호대교 사이 오수배출시설 개선 및 보행자 교각 설치
# 4  여성가족정책관  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!”
#
#                                                 제안취지  \
# 0      대프리카라고불리는대구시에물놀이장을각구마다설치하여주민들의편의를도모하는데목적이있습니다
# 1  신천동로에있는신성교신천철도교신천교동신교중앙분리대교각주변나대지에는콘크트로덮여있음신성교...
# 2     효신초등학교등굣길에위치한구동부정류장담벼락보기흉한상태로방치되어도시미관을크게훼손하고있어
# 3  침산교금호대교사이오수배출시설에대한환경개선및보행자통행을위한교각을설치하여산책하는시민에게...
# 4  일본군위안부문제를올바르게해결하고전쟁없는평화로운미래와여성인권이지켜지는양성평등한세상을대...
#
#                                                 사업내용
# 0  현재수도권지역이나다른광역시에서는여름이되면각구마다물놀이를할수있는수영장을설치하여주민들이...
# 1  신천동로신성교신천철도교신천교동신교교각주변녹지공간조성사업기간201826사업비90000...
# 2  구동부정류장담장도색보호팬스설치후장미넝쿨식재도색팬스설치장미넝쿨식재및관리는신천4동노숙인...
# 3  신천과금호강변은많은대구시민이산책걷기마라톤자전거등을즐기는곳인데침산교와금호대교사이에설치...
# 4  사업명제8회평화와인권을위한대구시민걷기대회양성평등한세상함께만들어요추진기간2017년6월...

# %% [markdown]
# ## Match Department
#
# First by using TF-IDF, pick keyword of each department.<br>
# And then, match department if no_team content has same words over 20.

# %%
df_team = df1[df1['부서'].notnull()].reset_index(drop=True)
df_noteam = df1[df1['부서'].isnull()].reset_index(drop=True)

df_team['text'] = df_team['사업명'] + ' ' + df_team['제안취지'] + ' ' + df_team['사업내용'] + ' '

# %%
df_team.head()
# Out:
#         부서                                      사업명  \
# 0    자연재난과                     무더운 대구의 여름을 위한 물놀이사업
# 1    공원녹지과                 신천동로 중앙분리대 교각 주변 녹지공간 조성
# 2   도시디자인과                  참 좋은 일자리가 만들어가는 학교 가는 길
# 3  여성가족정책관  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!”
# 4      도로과               신천4동 제1경로당 앞 경사로 미끄럼 방지 공사
#
#                                                 제안취지  \
# 0      대프리카라고불리는대구시에물놀이장을각구마다설치하여주민들의편의를도모하는데목적이있습니다
# 1  신천동로에있는신성교신천철도교신천교동신교중앙분리대교각주변나대지에는콘크트로덮여있음신성교...
# 2     효신초등학교등굣길에위치한구동부정류장담벼락보기흉한상태로방치되어도시미관을크게훼손하고있어
# 3  일본군위안부문제를올바르게해결하고전쟁없는평화로운미래와여성인권이지켜지는양성평등한세상을대...
# 4  신천4동제1경로당앞경사로는비또는눈이올경우많이미끄럽습니다예전에조성된경사가가파른골목이기...
#
#                                                 사업내용  \
# 0  현재수도권지역이나다른광역시에서는여름이되면각구마다물놀이를할수있는수영장을설치하여주민들이...
# 1  신천동로신성교신천철도교신천교동신교교각주변녹지공간조성사업기간201826사업비90000...
# 2  구동부정류장담장도색보호팬스설치후장미넝쿨식재도색팬스설치장미넝쿨식재및관리는신천4동노숙인...
# 3  사업명제8회평화와인권을위한대구시민걷기대회양성평등한세상함께만들어요추진기간2017년6월...
# 4                              아스콘등을이용한토목공사첨부파일hwp참조
#
#                                                 text
# 0  무더운 대구의 여름을 위한 물놀이사업 대프리카라고불리는대구시에물놀이장을각구마다설치하...
# 1  신천동로 중앙분리대 교각 주변 녹지공간 조성 신천동로에있는신성교신천철도교신천교동신교...
# 2  참 좋은 일자리가 만들어가는 학교 가는 길 효신초등학교등굣길에위치한구동부정류장담벼락...
# 3  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!” 일본군위안부...
# 4  신천4동 제1경로당 앞 경사로 미끄럼 방지 공사 신천4동제1경로당앞경사로는비또는눈이...

# %%
# make new df with project contents according to department
L_team = list(df_team['부서'].unique())
D_team = pd.DataFrame({'부서':L_team})
D_team['민원합산'] = ''

for i in range(D_team.shape[0]) :
    text = ''
    team = D_team.loc[i, '부서']

    for j in range(df_team.shape[0]) :
        if df_team.loc[j, '부서'] == team :
            text = text + df_team.loc[j, 'text']
    
    D_team.loc[i, '민원합산'] = text

D_team.head()
# Out:
#         부서                                               민원합산
# 0    자연재난과  무더운 대구의 여름을 위한 물놀이사업 대프리카라고불리는대구시에물놀이장을각구마다설치하...
# 1    공원녹지과  신천동로 중앙분리대 교각 주변 녹지공간 조성 신천동로에있는신성교신천철도교신천교동신교...
# 2   도시디자인과  참 좋은 일자리가 만들어가는 학교 가는 길 효신초등학교등굣길에위치한구동부정류장담벼락...
# 3  여성가족정책관  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!” 일본군위안부...
# 4      도로과  신천4동 제1경로당 앞 경사로 미끄럼 방지 공사 신천4동제1경로당앞경사로는비또는눈이...

# %%
from tqdm import tqdm
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Okt
from pykospacing import Spacing

okt = Okt()
spacing = Spacing()

#불용어 읽어오기
stopwords = pd.read_csv("stopwords.txt")
stopwords = stopwords['word'].tolist()

"""
#외래어 읽어오기
loanwords = pd.read_csv('loanwords.txt', encoding = 'cp949')
loanwords = loanwords['word'].tolist()
for word in loanwords :
    okt.add_dictionary(word, 'Noun')
"""
# Out:
# "\n#외래어 읽어오기\nloanwords = pd.read_csv('loanwords.txt', encoding = 'cp949')\nloanwords = loanwords['word'].tolist()\nfor word in loanwords :\n    okt.add_dictionary(word, 'Noun')\n"

# %%
# remove stopwords + tokeninzing
content = D_team['민원합산'].tolist()
D_team['민원토큰'] = ''

tks=[]
for i in range(len(content)) :
    sentence = content[i]
    kospacing_sent = spacing(sentence) # 띄워쓰기 보완
    noun_sent = okt.nouns(kospacing_sent) # 명사만 추출
    over_two_sent = [word for word in noun_sent if len(word) > 1]   # 2글자 이상인 단어만 사용
    stopwords_removed_sentence = [word for word in over_two_sent if not word in stopwords] # 불용어 제거
    D_team.at[i, '민원토큰'] = stopwords_removed_sentence
    tks.append(stopwords_removed_sentence)

clean_sents = []
for tk in tks :
    clean_sents.append(" ".join(tk))

D_team.head()
# Out:
#         부서                                               민원합산  \
# 0    자연재난과  무더운 대구의 여름을 위한 물놀이사업 대프리카라고불리는대구시에물놀이장을각구마다설치하...
# 1    공원녹지과  신천동로 중앙분리대 교각 주변 녹지공간 조성 신천동로에있는신성교신천철도교신천교동신교...
# 2   도시디자인과  참 좋은 일자리가 만들어가는 학교 가는 길 효신초등학교등굣길에위치한구동부정류장담벼락...
# 3  여성가족정책관  제8회평화와인권을위한대구시민걷기대회 “양성평등한 세상 함께 만들어요!” 일본군위안부...
# 4      도로과  신천4동 제1경로당 앞 경사로 미끄럼 방지 공사 신천4동제1경로당앞경사로는비또는눈이...
#
#                                                 민원토큰
# 0  [대구, 여름, 물놀이, 사업, 프리, 카라, 대구시, 물놀이, 구마, 설치, 주민...
# 1  [신천동로, 중앙, 분리, 교각, 주변, 녹지, 공간, 조성, 신천동로, 성교, 신...
# 2  [일자리, 학교, 초등학교, 등굣길, 위치, 구동, 정류장, 담벼락, 보기, 상태,...
# 3  [평화, 인권, 대구, 시민, 걷기, 대회, 양성평등, 세상, 일본군, 위안부, 문...
# 4  [신천, 경로당, 경사, 미끄럼, 방지, 공사, 신천, 경로당, 경사, 경우, 예전...

# %%
print(tv_array[4, i] for i in range(4364) if tv_array[4,i]>0 )
# Out:
# <generator object <genexpr> at 0x00000299089DF248>

# %%
for i in range(3464) :
    if tv_array[0, i] > 0.1 :
        print(tv_array[0, i])
# Out:
# 0.1203267382250565
# 0.10144060770244107
# 0.16057702735480311
# 0.17602817139570967
# 0.13249562427659364
# 0.1272843366921625
# 0.21723558936554743
# 0.1094843368328203
# 0.27898391226796326
# 0.15710037794206697
# 0.3693660226826866
# 0.17856694308599053
# 0.13572538924051314
# 0.22713535590273196
# 0.1066820296579482
# 0.11633604792043983
# 0.1203267382250565
# 0.1203267382250565

# %%
import time

tv = TfidfVectorizer()
tv_array = tv.fit_transform(clean_sents).toarray()  #문장별 단어 tfidf 값을 가진 [46,3464] 배열
tv_vocab = {v:k for k,v in tv.vocabulary_.items()}  #단어고유번호:단어 딕셔너리

for i, sent in enumerate(tv_array):
    print('====== document[%d] ======' % i)
    main_words=[]

    for j in range(len(sent)) :
        
        if sent[j] > 0.2 :
            ww = tv_vocab.get(j)
            vv = sent[j]
            main_words.append((ww,vv))
            
    print(len(main_words), ' : ', main_words)
    time.sleep(1)
# Out:
# ====== document[0] ======
# 4  :  [('산책로', 0.21723558936554743), ('설치', 0.27898391226796326), ('신천', 0.3693660226826866), ('자전거', 0.22713535590273196)]
# ====== document[1] ======
# 1  :  [('녹지', 0.2634859075888648)]
# ====== document[2] ======
# 3  :  [('벽화', 0.29346220340660883), ('신천', 0.2270925492681794), ('지하차도', 0.3635935865782498)]
# ====== document[3] ======
# 5  :  [('대회', 0.27265530798644444), ('세상', 0.2626200869781123), ('양성평등', 0.35488753319325933), ('위원회', 0.23659168879550624), ('인권', 0.3282751087226404)]
# ====== document[4] ======
# 4  :  [('도로', 0.2567334742356847), ('설치', 0.2173002162915046), ('인도', 0.297003105212914), ('차량', 0.20082167154552089)]
# ====== document[5] ======
# 1  :  [('도서관', 0.80214580217153)]
# ====== document[6] ======
# 6  :  [('공연', 0.3432659824183955), ('동호회', 0.22116937481506482), ('먹거리', 0.30035773461609605), ('시장', 0.483778191613808), ('칠성', 0.21454123901149716), ('풍물패', 0.22116937481506482)]
# ====== document[7] ======
# 2  :  [('설치', 0.2697623641584311), ('자전거', 0.6146743810277466)]
# ====== document[8] ======
# 6  :  [('구간', 0.33484738381915874), ('복개', 0.577928704052309), ('조성', 0.24010152349173064), ('철도', 0.2178956263374155), ('철로', 0.3100065759457119), ('테마', 0.32684343950612327)]
# ====== document[9] ======
# 3  :  [('신교', 0.22818556361417364), ('신천', 0.2646280171048614), ('화장실', 0.5219642318246198)]
# ====== document[10] ======
# 6  :  [('공원', 0.2042873892608057), ('놀이터', 0.24694716275753612), ('농구장', 0.22246561076116347), ('조성', 0.23310021760702634), ('체육', 0.2654947310237188), ('화원', 0.22246561076116347)]
# ====== document[11] ======
# 3  :  [('이야기', 0.2756636086760735), ('자리', 0.2194301353649792), ('청년', 0.6676151226353932)]
# ====== document[12] ======
# 8  :  [('강변', 0.2102313226769752), ('남구', 0.270362318095472), ('벚꽃', 0.2422900794961578), ('보라', 0.20596870318819163), ('산업', 0.21187646642372832), ('상영', 0.2751269241833153), ('영화', 0.25365156867670935), ('출판', 0.3053947377732871)]
# ====== document[13] ======
# 4  :  [('램프', 0.7563553926237541), ('메탈', 0.25211846420791806), ('수명', 0.25211846420791806), ('효율', 0.2608670161334145)]
# ====== document[14] ======
# 3  :  [('산격', 0.2095838628055431), ('제비', 0.2095838628055431), ('조형', 0.24449943783107853)]
# ====== document[15] ======
# 10  :  [('무단', 0.23861782710318366), ('무인', 0.20656750270355587), ('방위', 0.2292928200607598), ('방지', 0.20863170327051964), ('설치', 0.23553118918453617), ('안전', 0.26535953025745335), ('택배', 0.3439392300911397), ('투기', 0.22739167022608378), ('폐기물', 0.20656750270355587), ('휀스', 0.30985125405533376)]
# ====== document[16] ======
# 5  :  [('교량', 0.32734594279979284), ('내부', 0.292011105913735), ('벽면', 0.3404203569101386), ('천정', 0.5055783605323008), ('콘크리트', 0.20524707460301467)]
# ====== document[17] ======
# 5  :  [('공영', 0.277121070373147), ('야간', 0.3386460945231274), ('이용', 0.21505742812616613), ('조명', 0.41014874874942764), ('주차장', 0.46880473829920727)]
# ====== document[18] ======
# 3  :  [('불법', 0.42213346661496814), ('투기', 0.42213346661496814), ('환경', 0.23817928582581227)]
# ====== document[19] ======
# 3  :  [('공원', 0.2589451722635393), ('복개', 0.5857884699481758), ('철길', 0.46853231012886504)]
# ====== document[20] ======
# 4  :  [('반려', 0.25514770580034374), ('반려견', 0.28349745088927086), ('반려동물', 0.522749492710051), ('애완견', 0.2459997612753181)]
# ====== document[21] ======
# 6  :  [('도동', 0.2383109081231261), ('문화', 0.23742017426873754), ('연구', 0.2573139175698538), ('예술', 0.31438992788382614), ('측백나무', 0.2859730897477513), ('후계', 0.2383109081231261)]
# ====== document[22] ======
# 5  :  [('공단', 0.4210069958321232), ('방범', 0.31870143489238), ('보안', 0.31870143489238), ('설치', 0.22523088132841698), ('취약', 0.31870143489238)]
# ====== document[23] ======
# 3  :  [('미세먼지', 0.7021317361497321), ('설치', 0.2347671049816635), ('신호등', 0.3878301629754734)]
# ====== document[24] ======
# 2  :  [('발원', 0.312294165465432), ('생태관광', 0.4804525622545108)]
# ====== document[25] ======
# 3  :  [('설치', 0.42474976710170337), ('신천', 0.28221487139319146), ('좌회전', 0.21373957085420303)]
# ====== document[26] ======
# 3  :  [('시설', 0.32199971352787193), ('신천', 0.20980738022684073), ('화장실', 0.40644365145850603)]
# ====== document[27] ======
# 7  :  [('방범', 0.38027409492616926), ('산책로', 0.21194587264786408), ('생활', 0.27015301695671173), ('설치', 0.29561968095016733), ('안전', 0.33911339623658254), ('인근', 0.21194587264786408), ('회전교차로', 0.2474819516302192)]
# ====== document[28] ======
# 3  :  [('반려동물', 0.20222830808185754), ('설치', 0.24705383366160694), ('조성', 0.2600846365052759)]
# ====== document[29] ======
# 5  :  [('도서관', 0.65811236442558), ('메타', 0.22419130527499398), ('버스', 0.23174173238746978), ('살균', 0.20669178938223973), ('플랫폼', 0.22419130527499398)]
# ====== document[30] ======
# 8  :  [('버스', 0.2995364148643833), ('버스정류장', 0.30879043075886836), ('복지', 0.20415342495674152), ('설치', 0.20390894431580678), ('승강장', 0.23159282306915127), ('의자', 0.21423232702594636), ('정류장', 0.34773258558484405), ('행정', 0.20415342495674152)]
# ====== document[31] ======
# 7  :  [('게양', 0.20255892697218433), ('배포', 0.2737248271699158), ('세트', 0.20255892697218433), ('와이파이', 0.3038383904582765), ('음악', 0.23578622421005319), ('지하도', 0.25235891399399735), ('태극기', 0.5063973174304608)]
# ====== document[32] ======
# 4  :  [('건널목', 0.22518635772273102), ('사고', 0.2114179286830529), ('소수력발전', 0.24996000980635968), ('우회', 0.30472586626292564)]
# ====== document[33] ======
# 4  :  [('네거리', 0.24919663867459257), ('바닥', 0.2011331639928583), ('설치', 0.31805939045570675), ('신호등', 0.32567802342963204)]
# ====== document[34] ======
# 2  :  [('설치', 0.2805684590756777), ('신천', 0.35866904524510507)]
# ====== document[35] ======
# 4  :  [('건강', 0.2161515494346609), ('슬레이트', 0.2884437793867958), ('지붕', 0.2598559831158996), ('폐가', 0.2884437793867958)]
# ====== document[36] ======
# 7  :  [('가게', 0.2060349373296083), ('소규모', 0.2721737039900353), ('약국', 0.24806464232085373), ('음식점', 0.3352182614769034), ('장애인', 0.44695768196920466), ('점포', 0.3720969634812806), ('휠체어', 0.2060349373296083)]
# ====== document[37] ======
# 8  :  [('개나리꽃', 0.26471561470613647), ('공원', 0.4051417328417526), ('두산', 0.2581715213314028), ('둘레길', 0.23847952780201898), ('뒤편', 0.2581715213314028), ('분위기', 0.24487219157765622), ('위브', 0.27390128981336104), ('함지', 0.36644121317111605)]
# ====== document[38] ======
# 4  :  [('금연', 0.49831651488356593), ('담배', 0.35914250784882235), ('설치', 0.20474968437253033), ('흡연', 0.29898990893013955)]
# ====== document[39] ======
# 2  :  [('전기차', 0.7051636577381855), ('충전', 0.49620428382038567)]
# ====== document[40] ======
# 10  :  [('계단', 0.26940597837919966), ('도달', 0.20374379741695428), ('레일', 0.20374379741695428), ('설치', 0.2092870543520387), ('신천역', 0.35652967215491854), ('에스켈레이터', 0.20374379741695428), ('지붕', 0.2753259832510691), ('지하철', 0.3162206107444382), ('지하철역', 0.20374379741695428), ('출구', 0.20205448378439977)]
# ====== document[41] ======
# 4  :  [('설치', 0.3043560256582833), ('심장', 0.43209648942092055), ('자동', 0.2871089480072961), ('충격', 0.31141696533890934)]
# ====== document[42] ======
# 5  :  [('격동', 0.22713363414409987), ('동산', 0.44118545856370794), ('보라', 0.4250985269248912), ('치기', 0.20940445131246288), ('해충', 0.6282133539373886)]

# %%
tv_array[0, 3463]
# Out:
# 0.006762707180162737

# %%
for id, s in enumerate( tfidfScorer(corpus) ):
    s = sorted(s, key=lambda x:x[1], reverse=True)
    print('[%d] %s ...' % (id, s[:10]))
[출처] [파이썬을 이용한 한글 NLP] 05. TF-IDF 기반 키워드 추출기|작성자 VG
